# %% [markdown]
# # 구별 유동인구 수

# %%
import pandas as pd # Python Data Analysis Library

# %%
import json # JSON encoder and decoder
import folium # Python library used for visualizing geospatial data

# %%
from folium import plugins

# %%
# import library: time
import time
now = time.localtime() # used to add timestamp to filename

# %%
#folium.__version__

# %%
gufile = pd.read_excel('./files/guflopop.xlsx')

# %%
gufile.head()
# Out:
#   dist   val
# 0  강남구  7048
# 1  강동구  6776
# 2  강북구  5049
# 3  강서구  4038
# 4  관악구  8257

# %%
gufile.sort_values(by='val', ascending='True').head(25)
# Out:
#     dist    val
# 24   중랑구   3079
# 16   성북구   3084
# 9    도봉구   3325
# 10  동대문구   3419
# 17   송파구   3605
# 12   마포구   3939
# 18   양천구   4026
# 3    강서구   4038
# 8    노원구   4066
# 20   용산구   4398
# 19  영등포구   4488
# 15   성동구   4819
# 2    강북구   5049
# 5    광진구   5168
# 7    금천구   5183
# 21   은평구   5528
# 14   서초구   5583
# 6    구로구   6105
# 1    강동구   6776
# 0    강남구   7048
# 13  서대문구   7878
# 4    관악구   8257
# 11   동작구   8758
# 22   종로구  10569
# 23    중구  13615

# %%
seoulmappath  = './files/seoul_sgg.geojson'
seoulmap = json.load(open(seoulmappath, encoding='utf-8'))

# %%
loc = 'Flow Population by Distict, SEOUL'
loc = '서울시 구별 유동인구수'
title_html = '''
             <head>
             <meta charset="utf-8">
             </head>
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)

# %%
facChoro = folium.Map(
    location = [37.58585751211208, 126.97624264491466],
    tiles = 'cartodbpositron',
    zoom_start=11
)

choropleth = folium.Choropleth(
    geo_data = seoulmap,
    data = gufile,
    columns=['dist', 'val'],
    fill_color = 'YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.5,
    key_on='properties.SIG_KOR_NM'
    ).add_to(facChoro)


choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['SIG_KOR_NM'])
)

# %%
facChoro.get_root().html.add_child(folium.Element(title_html))

# %%
minimap = plugins.MiniMap()
facChoro.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
facChoro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
output_path = './output/'
file_name = 'vis-facChoro'
rel_path =  output_path + file_name + '_' + str(now.tm_mon).zfill(2) + str(now.tm_mday).zfill(2) + str(now.tm_hour).zfill(2) + str(now.tm_min).zfill(2) + '.html'

# %%
facChoro.save(rel_path)
